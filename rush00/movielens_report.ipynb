# %%
from movielens_analysis import Movies
from movielens_analysis import Tags
from movielens_analysis import Ratings
from movielens_analysis import Links
m = Movies("movies.csv")
m.read_csv()
t = Tags("tags.csv")
t.read_csv()
r = Ratings("ratings.csv")
r.read_csv()
l = Links("links.csv")
l.read_csv()

# %% [markdown]
# ## Класс Movies

# %% [markdown]
# ### Распределение фильмов по годам
# Можем заметить, что количество выпускаемых фильмов стремительно росло с 20 века,
# однако после 2000х фоличество фильмов держится примерно на одном уровне

# %%
# %timeit
m.dist_by_release()
# Out:
# OrderedDict([('2002', 311),
#              ('2006', 295),
#              ('2001', 294),
#              ('2007', 284),
#              ('2000', 283),
#              ('2009', 282),
#              ('2003', 279),
#              ('2004', 279),
#              ('2014', 278),
#              ('1996', 276),
#              ('2015', 274),
#              ('2005', 273),
#              ('2008', 269),
#              ('1999', 263),
#              ('1997', 260),
#              ('1995', 259),
#              ('1998', 258),
#              ('2011', 254),
#              ('2010', 247),
#              ('2013', 239),
#              ('1994', 237),
#              ('2012', 233),
#              ('2016', 218),
#              ('1993', 198),
#              ('1992', 167),
#              ('1988', 165),
#              ('1987', 153),
#              ('1990', 147),
#              ('1991', 147),
#              ('2017', 147),
#              ('1989', 142),
#              ('1986', 139),
#              ('1985', 126),
# ...

# %% [markdown]
# ### Распределение фильмов по жанрам
# Самыми полулярными жанрами являются Драма, Комедия и Экшен

# %%
# %timeit
m.dist_by_genres()
# Out:
# {'Drama': 4362,
#  'Comedy': 3756,
#  'Thriller': 1895,
#  'Action': 1830,
#  'Romance': 1599,
#  'Adventure': 1286,
#  'Crime': 1206,
#  'Sci-Fi': 980,
#  'Horror': 978,
#  'Fantasy': 779,
#  'Children': 690,
#  'Animation': 611,
#  'Mystery': 581,
#  'War': 451,
#  'Documentary': 440,
#  'Musical': 334,
#  'Western': 170,
#  'Film-Noir': 87,
#  '(no genres listed)': 34}

# %% [markdown]
# ### Мульти-жанровые фильмы
# На первом месте фильм 'Rubber'("Шина"), если открыть описание фильма становится понятно, откуда у него столько жанров.
# Шина - французский абсурдно-комедийный фильм ужасов 2010 года об автомобильной покрышке, которая ожила и стала убивать людей при помощи телекинеза.

# %%
# %timeit
m.most_genres(5)
# Out:
# {'Rubber ': 10,
#  'Patlabor: The Movie Kidô keisatsu patorebâ: The Movie) ': 8,
#  'Mulan ': 7,
#  'Who Framed Roger Rabbit? ': 7,
#  'Osmosis Jones ': 7}

# %% [markdown]
# ## Класс Tags

# %% [markdown]
# ### Самые длинные тэги

# %%
# %timeit
t.longest(100)
# Out:
# ['Something for everyone in this one... saw it without and plan on seeing it with kids!',
#  'the catholic church is the most corrupt organization in history',
#  'villain nonexistent or not needed for good story',
#  'r:disturbing violent content including rape',
#  '06 Oscar Nominated Best Movie - Animation',
#  'stop using useless characters for filler',
#  'Academy award (Best Supporting Actress)',
#  'Oscar (Best Effects - Visual Effects)',
#  'r:sustained strong stylized violence',
#  'It was melodramatic and kind of dumb',
#  'audience intelligence underestimated',
#  'Oscar (Best Music - Original Score)',
#  'Oscar (Best Supporting Actress)',
#  'start of a beautiful friendship',
#  'assassin-in-training (scene)',
#  'Oscar (Best Cinematography)',
#  'r:disturbing violent images',
#  'Everything you want is here',
#  'political right versus left',
#  'avant-garde romantic comedy',
#  'Not available from Netflix',
#  'representation of children',
# ...

# %% [markdown]
# ### Самые длинные тэги по количеству слов

# %%
# %timeit
t.most_words(100)
# Out:
# {'Something for everyone in this one... saw it without and plan on seeing it with kids!': 16,
#  'the catholic church is the most corrupt organization in history': 10,
#  'villain nonexistent or not needed for good story': 8,
#  'It was melodramatic and kind of dumb': 7,
#  'r:disturbing violent content including rape': 6,
#  'stop using useless characters for filler': 6,
#  '06 Oscar Nominated Best Movie - Animation': 6,
#  'a dingo ate my baby': 5,
#  'r:sustained strong stylized violence': 5,
#  'GIVE ME BACK MY SON!': 5,
#  'Oscar (Best Effects - Visual Effects)': 5,
#  'Everything you want is here': 5,
#  'Academy award (Best Supporting Actress)': 5,
#  'based on a true story': 5,
#  'based on a TV show': 5,
#  'stupid is as stupid does': 5,
#  'start of a beautiful friendship': 5,
#  'Oscar (Best Music - Original Score)': 5,
#  'stop looking at me swan': 5,
#  'lord of the rings': 4,
#  'assassin-in-training (scene)': 4,
#  'No DVD at Netflix': 4,
# ...

# %% [markdown]
# ### Самые длинные тэги по количеству букв и слов

# %%
# %timeit
t.most_words_and_longest(100)
# Out:
# ['seen more than once',
#  'Nudity (Full Frontal)',
#  'heroine in tight suit',
#  'coulda been a contender',
#  'Rita Hayworth can dance!',
#  'salute to Douglas Sirk',
#  'Oscar (Best Music - Original Score)',
#  'James Fennimore Cooper',
#  'Oscar (Best Effects - Visual Effects)',
#  'non-linear timeline',
#  'android(s)/cyborg(s)',
#  'avant-garde romantic comedy',
#  'Not available from Netflix',
#  'r:strong bloody violence',
#  'fast-paced dialogue',
#  'They Might Be Giants',
#  'Something for everyone in this one... saw it without and plan on seeing it with kids!',
#  'It was melodramatic and kind of dumb',
#  'based on a true story',
#  'setting:space/space ship',
#  'May-December romance',
#  'rich guy - poor girl',
#  'a dingo ate my baby',
#  'r:disturbing violent images',
#  'stop looking at me swan',
#  'political right versus left',
#  'Strangers on a Train',
#  'lack of development',
#  'stop using useless characters for filler',
#  'first was much better',
# ...

# %% [markdown]
# ### Самые популярные тэги

# %%
# %timeit
t.most_popular(100)
# Out:
# {'In Netflix queue': 131,
#  'atmospheric': 36,
#  'superhero': 24,
#  'thought-provoking': 24,
#  'funny': 23,
#  'Disney': 23,
#  'surreal': 23,
#  'religion': 22,
#  'sci-fi': 21,
#  'dark comedy': 21,
#  'quirky': 21,
#  'psychology': 21,
#  'suspense': 20,
#  'twist ending': 19,
#  'visually appealing': 19,
#  'crime': 19,
#  'politics': 18,
#  'music': 16,
#  'time travel': 16,
#  'mental illness': 16,
#  'dark': 15,
#  'comedy': 15,
#  'aliens': 15,
#  'space': 14,
#  'mindfuck': 14,
#  'dreamlike': 14,
#  'black comedy': 13,
#  'emotional': 13,
#  'heist': 13,
#  'anime': 12,
#  'action': 12,
#  'satire': 12,
#  'high school': 12,
#  'disturbing': 12,
#  'Shakespeare': 12,
#  'journalism': 12,
#  'Stephen King': 12,
#  'court': 12,
#  'imdb top 250': 11,
#  'comic book': 11,
#  'classic': 11,
#  'psychological': 11,
#  'Holocaust': 11,
#  'adolescence': 11,
#  'adultery': 11,
#  'boxing': 11,
#  'drugs': 10,
#  'Leonardo DiCaprio': 10,
#  'Mafia': 10,
#  'animation': 10,
# ...

# %% [markdown]
# ### Тэги включающие определенное слово

# %%
# %timeit
t.tags_with("Netflix")
# Out:
# ['In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
#  'In Netflix queue',
# ...

# %% [markdown]
# ## Класс Ratings

# %% [markdown]
# Количество фильмов в год

# %%
# %timeit
r.get_movies().dist_by_year()
# Out:
# {1996: 6040,
#  1997: 1916,
#  1998: 507,
#  1999: 2439,
#  2000: 10061,
#  2001: 3922,
#  2002: 3478,
#  2003: 4014,
#  2004: 3279,
#  2005: 5813,
#  2006: 4059,
#  2007: 7114,
#  2008: 4351,
#  2009: 4158,
#  2010: 2300,
#  2011: 1690,
#  2012: 4657,
#  2013: 1664,
#  2014: 1439,
#  2015: 6616,
#  2016: 6702,
#  2017: 8199,
#  2018: 6418}

# %% [markdown]
# Количество оценок, встречающихся в файле

# %%
# %timeit
r.get_movies().dist_by_rating()
# Out:
# {'0.5': 1370,
#  '1.0': 2811,
#  '1.5': 1791,
#  '2.0': 7551,
#  '2.5': 5550,
#  '3.0': 20047,
#  '3.5': 13136,
#  '4.0': 26818,
#  '4.5': 8551,
#  '5.0': 13211}

# %% [markdown]
# Рейтингфильмов по количеству оценок

# %%
# %timeit
r.get_movies().top_by_num_of_ratings(10)
# Out:
# {'Forrest Gump ': 329,
#  '"Shawshank Redemption The ': 317,
#  'Pulp Fiction ': 307,
#  '"Silence of the Lambs The ': 279,
#  '"Matrix The ': 278,
#  'Star Wars: Episode IV - A New Hope ': 251,
#  'Jurassic Park ': 238,
#  'Braveheart ': 237,
#  'Terminator 2: Judgment Day ': 224,
#  "Schindler's List ": 220}

# %% [markdown]
# Медиана/Среднее арифметическое ретингов фильмов

# %%
# %timeit
r.get_movies().top_by_ratings(10, "mediana")
# Out:
# {'Lamerica ': 5.0,
#  'Angels and Insects ': 5.0,
#  'Heidi Fleiss: Hollywood Madam ': 5.0,
#  '"Awfully Big Adventure An ': 5.0,
#  'Live Nude Girls ': 5.0,
#  'In the Realm of the Senses Ai no corrida) ': 5.0,
#  'What Happened Was... ': 5.0,
#  '"Thin Line Between Love and Hate A ': 5.0,
#  'Denise Calls Up ': 5.0,
#  'Supercop 2 Project S) Chao ji ji hua) ': 5.0}

# %% [markdown]
# Среднеквадратичное отклонение

# %%
# %timeit
r.get_movies().top_controversial(10)
# Out:
# {'Fanny and Alexander Fanny och Alexander) ': 5.06,
#  "Ivan's Childhood a.k.a. My Name is Ivan) Ivanovo detstvo) ": 5.06,
#  'Troll 2 ': 4.5,
#  'Lassie ': 4.0,
#  'Emma ': 4.0,
#  '"Zed & Two Noughts A ': 4.0,
#  'Kwaidan Kaidan) ': 4.0,
#  'Play Time a.k.a. Playtime) ': 3.72,
#  '"Room The ': 3.56,
#  'Peeping Tom ': 3.5}

# %% [markdown]
# Количество оценок по юзерам

# %%
# %timeit
r.get_users().first_method()
# Out:
# Counter({'1': 232,
#          '2': 29,
#          '3': 39,
#          '4': 216,
#          '5': 44,
#          '6': 314,
#          '7': 152,
#          '8': 47,
#          '9': 46,
#          '10': 140,
#          '11': 64,
#          '12': 32,
#          '13': 31,
#          '14': 48,
#          '15': 135,
#          '16': 98,
#          '17': 105,
#          '18': 502,
#          '19': 703,
#          '20': 242,
#          '21': 443,
#          '22': 119,
#          '23': 121,
#          '24': 110,
#          '25': 26,
#          '26': 21,
#          '27': 135,
#          '28': 570,
#          '29': 81,
#          '30': 34,
#          '31': 50,
#          '32': 102,
#          '33': 156,
#          '34': 86,
#          '35': 23,
#          '36': 60,
#          '37': 21,
#          '38': 78,
#          '39': 100,
#          '40': 103,
#          '41': 217,
#          '42': 440,
#          '43': 114,
#          '44': 48,
#          '45': 399,
#          '46': 42,
# ...

# %% [markdown]
# Медиана/Среднее оценок по юзерам

# %%
# %timeit
r.get_users().second_method('average')
# Out:
# {'53': 5.0,
#  '251': 4.87,
#  '515': 4.85,
#  '25': 4.81,
#  '30': 4.74,
#  '523': 4.69,
#  '348': 4.67,
#  '171': 4.63,
#  '452': 4.56,
#  '43': 4.55,
#  '371': 4.55,
#  '122': 4.55,
#  '441': 4.52,
#  '400': 4.51,
#  '52': 4.48,
#  '538': 4.47,
#  '417': 4.46,
#  '168': 4.46,
#  '543': 4.45,
#  '106': 4.44,
#  '601': 4.43,
#  '319': 4.43,
#  '475': 4.41,
#  '413': 4.41,
#  '188': 4.4,
#  '276': 4.39,
#  '12': 4.39,
#  '581': 4.38,
#  '533': 4.38,
#  '154': 4.38,
#  '69': 4.37,
#  '586': 4.37,
#  '1': 4.37,
#  '59': 4.36,
#  '544': 4.36,
#  '128': 4.36,
#  '459': 4.35,
#  '253': 4.35,
#  '585': 4.34,
#  '553': 4.34,
#  '519': 4.33,
#  '70': 4.32,
#  '435': 4.32,
#  '336': 4.32,
#  '300': 4.3,
#  '93': 4.29,
#  '532': 4.28,
#  '74': 4.27,
#  '80': 4.26,
#  '49': 4.26,
#  '291': 4.26,
#  '224': 4.26,
#  '398': 4.25,
#  '246': 4.25,
#  '169': 4.25,
#  '164': 4.25,
#  '362': 4.24,
#  '209': 4.24,
#  '162': 4.24,
#  '494': 4.23,
#  '250': 4.22,
#  '573': 4.21,
#  '340': 4.21,
# ...

# %% [markdown]
# Отклонение оценок по юзерам

# %%
# %timeit
r.get_users().third_method(5)
# Out:
# {'3': 4.26, '461': 3.1, '55': 3.09, '259': 2.94, '329': 2.92}

# %% [markdown]
# ## Класс Links

# %% [markdown]
# Общая информация о заданных фильмах с сайта imbd

# %%
l.get_imdb(['52', '20', '45', '122'], ['movieId', 'Director', 'Budget', 'Cumulative Worldwide Gross', 'Runtime'])
# Out:
# {122: [122, 'Reginald Hudlin', '$42,000,000', '$131,052,444', '1 hour 57 minutes'], 52: [52, 'Woody Allen', '$15,000,000', '$6,468,498', '1 hour 35 minutes'], 45: [45, 'Gus Van Sant', '$20,000,000', '$21,284,514', '1 hour 46 minutes'], 20: [20, 'Joseph Ruben', '$68,000,000', '$35,431,113', '1 hour 50 minutes']}
# [[122, 'Reginald Hudlin', '$42,000,000', '$131,052,444', '1 hour 57 minutes'],
#  [52, 'Woody Allen', '$15,000,000', '$6,468,498', '1 hour 35 minutes'],
#  [45, 'Gus Van Sant', '$20,000,000', '$21,284,514', '1 hour 46 minutes'],
#  [20, 'Joseph Ruben', '$68,000,000', '$35,431,113', '1 hour 50 minutes']]
